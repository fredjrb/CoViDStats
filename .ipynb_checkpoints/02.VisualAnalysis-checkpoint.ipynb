# %% [markdown]
# <H1> MONTAGEM DOS DADOS </H1>

# %% [markdown]
# ***
# ## <font color="#106eb2" size=12>Projeto CoViData</font>
# ***

# %% [markdown]
# ***
# ## <font color="#106eb2" size=6>Notebook 02 - Análise Visual dos Dados</font>
# ***

# %% [markdown]
# <h1>Raspagem dos dados de Piramide Populacional<h1>

# %% [markdown]
# ### - Livro de Estatistica / Subir Notebook do Curso / Subir este notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mplt
import seaborn as sns
import statsmodels.api as sm
from matplotlib.gridspec import GridSpec

# %% [markdown]
# <H1>Leitura dos dados consolidados </H1>

# %%
df = pd.read_csv('data/consolidadoOWID.csv', sep = ',')
df.head()
df.dropna(subset=['MORTES_POR_MILHAO', 'CASOS_POR_MILHAO'], inplace=True)

# %%
df.isna().sum()
# Out:
# AREA                            0
# PAIS                            0
# CONTINENTE                      0
# SUB_REGIAO                      0
# ISO                             0
# 0-4                             0
# 5-9                             0
# 10-14                           0
# 15-19                           0
# 20-24                           0
# 25-29                           0
# 30-34                           0
# 35-39                           0
# 40-44                           0
# 45-49                           0
# 50-54                           0
# 55-59                           0
# 60-64                           0
# 65-69                           0
# 70-74                           0
# 75-79                           0
# 80-84                           0
# 85-89                           0
# 90-94                           0
# 95-99                           0
# 100+                            0
# POPULACAO                       0
# ...

# %%
df.head()
# Out:
#       AREA           PAIS        CONTINENTE          SUB_REGIAO  ISO  \
# 0  9388211          CHINA              ASIA        EASTERN ASIA  CHN
# 1  2973190          INDIA              ASIA       SOUTHERN ASIA  IND
# 2  9147420  UNITED STATES  AMERICA DO NORTE    NORTHERN AMERICA  USA
# 3  1811570      INDONESIA              ASIA  SOUTH-EASTERN ASIA  IDN
# 4   770880       PAKISTAN              ASIA       SOUTHERN ASIA  PAK
#
#            0-4          5-9        10-14        15-19        20-24  ...  \
# 0   82832536.0   80530944.0   77715286.0   74503800.0   85502189.0  ...
# 1  116320763.0  116134270.0  116406628.0  116858691.0  115304620.0  ...
# 2   20438539.0   20200409.0   20769978.0   21038355.0   21899476.0  ...
# 3   20478078.0   21201103.0   22058099.0   22512791.0   22234259.0  ...
# 4   29778193.0   28245207.0   26050219.0   23773611.0   21298570.0  ...
#
#         CASOS    MORTES  CASOS_POR_MILHAO  MORTES_POR_MILHAO  FATOR R  \
# ...

# %% [markdown]
# <H1>Gerando valores calculados </H1>

# %%
grupos_etarios = ['0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39',
                  '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75-79',
                  '80-84', '85-89', '90-94', '95-99', '100+']

for grupo_etario in grupos_etarios :
    df[grupo_etario] = df[grupo_etario] / df.POPULACAO

df.head()

df['DENSIDADE_POPULACIONAL'] = df.POPULACAO / df.AREA 
df['LETALIDADE'] = df.MORTES / df.CASOS

# %%
df.describe()
# Out:
#                AREA         0-4         5-9       10-14       15-19  \
# count  1.820000e+02  182.000000  182.000000  182.000000  182.000000
# mean   7.066917e+05    0.092324    0.089196    0.085207    0.080034
# std    1.890989e+06    0.041586    0.034166    0.028435    0.023362
# min    1.000000e+00    0.028668    0.027440    0.038009    0.039089
# 25%    2.806750e+04    0.059329    0.058949    0.058063    0.057743
# 50%    1.416550e+05    0.083845    0.083793    0.083874    0.080140
# 75%    5.685375e+05    0.122976    0.119540    0.111578    0.104279
# max    1.637687e+07    0.201346    0.164530    0.139953    0.118969
#
#             20-24       25-29       30-34       35-39       40-44  ...  \
# count  182.000000  182.000000  182.000000  182.000000  182.000000  ...
# mean     0.077614    0.076985    0.075153    0.070122    0.063091  ...
# std      0.017044    0.013609    0.013826    0.015105    0.015369  ...
# ...

# %%
df.columns
# Out:
# Index(['AREA', 'PAIS', 'CONTINENTE', 'SUB_REGIAO', 'ISO', '0-4', '5-9',
#        '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49',
#        '50-54', '55-59', '60-64', '65-69', '70-74', '75-79', '80-84', '85-89',
#        '90-94', '95-99', '100+', 'POPULACAO', 'URBANIZACAO', 'GINI',
#        'GASTOS_SAUDE', 'EXPECTATIVA_VIDA', 'DENSIDADE_MEDICOS',
#        'DENSIDADE_LEITOS_POR_MIL', 'PIB', 'DATA', 'CASOS', 'MORTES',
#        'CASOS_POR_MILHAO', 'MORTES_POR_MILHAO', 'FATOR R', 'PIB_PER_CAPITA',
#        'TAXA_MORTES_CARDIOVASCULAR', 'PREVALENCIA_DIABETES',
#        'LEITOS_HOSPITALARES_POR_MIL', 'IDH', 'DENSIDADE_POPULACIONAL',
#        'LETALIDADE'],
#       dtype='object')

# %% [markdown]
# <H1>Avaliação Visual das Informações</H1>

# %% [markdown]
# ## Avaliação Visual de Casos / Mortes por 100.000 (Histograma)

# %%
def make_histograma(dados : pd.Series, descricao : str, ax : mplt.axes.Axes):
    #Usando a Regra de Sturges para definir o número de bins
    k = int(1 + 10/3 * np.log10(df.shape[0]))

    sns.set_style("whitegrid")
    ax = sns.histplot(data=dados, bins=k*5, palette=sns.color_palette("husl", n_colors=1), kde=True, ax = ax)
    ax.set_title(f'Distribuição de Frequência de {descricao}', fontsize = 18)
    ax.set_xlabel(descricao.upper(), fontsize=16)
    ax.set_ylabel('NÚMERO DE PAíSES', fontsize=16)
    ax.figure.set_size_inches(20,10)
    return ax

# %%
fig = plt.figure(constrained_layout=True)
gs = GridSpec(2, 2, figure=fig)
fig.set_size_inches(20,40)

ax0 = fig.add_subplot(gs[0, 0])
ax1 = fig.add_subplot(gs[0, 1])
ax2 = fig.add_subplot(gs[1, 0])


make_histograma(df.CASOS_POR_MILHAO, 'casos por milhão de habitantes', ax0)
make_histograma(df.MORTES_POR_MILHAO, 'mortes por milhão de habitantes', ax1)
make_histograma(df.LETALIDADE, 'letalidade', ax2)
# Out:
# <AxesSubplot:title={'center':'Distribuição de Frequência de letalidade'}, xlabel='LETALIDADE', ylabel='NÚMERO DE PAíSES'>

# %% [markdown]
# ### BOXPLOTS

# %%
def make_bloxplot(dados : pd.Series, descricao : str, ax : mplt.axes.Axes) : 
    sns.set_palette(sns.diverging_palette(120, 0, l=25, n=1))
    ax = sns.boxplot(data=dados, orient='h', ax=ax)
    ax.figure.set_size_inches(20, 10)
    ax.set_title(f'Distribuição da Frequência de {descricao}' , fontsize=20)
    ax.set_xlabel(descricao.upper(), fontsize=14)
    ax.set_xlim(xmin=0, xmax=(dados.max() * 1.10))
    ax.grid(True)
    return ax

def outliers(series : pd.Series) :
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iiq = (q3 - q1)
    inf = q1 - (1.5 * iiq)
    sup = q3 + (1.5 * iiq)
    if (inf < 0) :
        inf = 0
    return inf, sup

# %%
fig = plt.figure(constrained_layout=True)
gs = GridSpec(2, 2, figure=fig)
fig.set_size_inches(40,40)

ax0 = fig.add_subplot(gs[0, 0])
ax1 = fig.add_subplot(gs[0, 1])
ax2 = fig.add_subplot(gs[1, 0])

make_bloxplot(df.CASOS_POR_MILHAO, 'Casos por Milhão de Habitantes', ax0)
make_bloxplot(df.MORTES_POR_MILHAO, 'Mortes por Milhão de Habitantes', ax1)
make_bloxplot(df.LETALIDADE, 'Letalidade', ax2)
# Out:
# <AxesSubplot:title={'center':'Distribuição da Frequência de Letalidade'}, xlabel='LETALIDADE'>

# %%
_, sup_casos = outliers(df.CASOS_POR_MILHAO)

print(f'Considera-se outliers no número de casos, países com mais de {sup_casos} casos por milhão habitantes')
paisesOutliersCasos =  pd.DataFrame()
paisesOutliersCasos = df.query(f'CASOS_POR_MILHAO > {sup_casos}')[['PAIS', 'CASOS_POR_MILHAO', 'CONTINENTE', 'SUB_REGIAO']]
paisesOutliersCasos.columns = ['PAIS', 'CASOS POR MILHAO', 'CONTINENTE', 'SUB REGIAO']
paisesOutliersCasos
# Out:
# Considera-se outliers no número de casos, países com mais de 171181.12199999997 casos por milhão habitantes
#            PAIS  CASOS POR MILHAO CONTINENTE       SUB REGIAO
# 182  SEYCHELLES        178370.958     AFRICA   EASTERN AFRICA
# 184     ANDORRA        185840.937     EUROPA  SOUTHERN EUROPE

# %%
_, sup_mortes = outliers(df.MORTES_POR_MILHAO)

print(f'Considera-se outliers no número de mortes, países com mais de {sup_mortes} casos por milhão habitantes')
paisesOutliersMortes =  pd.DataFrame()
paisesOutliersMortes = df.query(f'MORTES_POR_MILHAO > {sup_mortes}')[['PAIS', 'MORTES_POR_MILHAO', 'CONTINENTE', 'SUB_REGIAO']]
paisesOutliersMortes.columns = ['PAIS', 'MORTES POR MILHAO', 'CONTINENTE', 'SUB REGIAO']
paisesOutliersMortes
# Out:
# Considera-se outliers no número de mortes, países com mais de 2726.880875 casos por milhão habitantes
#                          PAIS  MORTES POR MILHAO      CONTINENTE  \
# 42                       PERU           5921.506  AMERICA LATINA
# 84   CZECH REPUBLIC (CZECHIA)           2832.949          EUROPA
# 92                    HUNGARY           3107.237          EUROPA
# 132    BOSNIA AND HERZEGOVINA           2947.134          EUROPA
#
#           SUB REGIAO
# 42     SOUTH AMERICA
# 84    EASTERN EUROPE
# 92    EASTERN EUROPE
# 132  SOUTHERN EUROPE

# %%
_, sup_letalidade = outliers(df.LETALIDADE)

print(f'Considera-se outliers na letalidade, países com letalidade superior a {sup_letalidade}')
paisesOutliersLetalidade =  pd.DataFrame()
paisesOutliersLetalidade = df.query(f'LETALIDADE > {sup_letalidade}')[['PAIS', 'LETALIDADE', 'CONTINENTE', 'SUB_REGIAO']]
paisesOutliersLetalidade.columns = ['PAIS', 'LETALIDADE', 'CONTINENTE', 'SUB REGIAO']
paisesOutliersLetalidade
# Out:
# Considera-se outliers na letalidade, países com letalidade superior a 0.04752511794632641
#         PAIS  LETALIDADE      CONTINENTE       SUB REGIAO
# 0      CHINA    0.050175            ASIA     EASTERN ASIA
# 9     MEXICO    0.088750  AMERICA LATINA  CENTRAL AMERICA
# 13     EGYPT    0.057978          AFRICA  NORTHERN AFRICA
# 33     SUDAN    0.074748          AFRICA  NORTHERN AFRICA
# 42      PERU    0.093219  AMERICA LATINA    SOUTH AMERICA
# 47     YEMEN    0.196078            ASIA     WESTERN ASIA
# 65     SYRIA    0.073723            ASIA     WESTERN ASIA
# 70   SOMALIA    0.051643          AFRICA   EASTERN AFRICA
# 169  VANUATU    0.250000         OCEANIA        MELANESIA

# %%
def box_plot_continente(df : pd.DataFrame, info : str, ax : mplt.axes.Axes = None):
    
    sns.set_style("whitegrid")
    classes = df.CONTINENTE.unique()
    classes.sort()
    
    if (ax == None) :
        ax = sns.boxplot(y='CONTINENTE', data=df, orient='h', x=info, order=classes,  palette=sns.color_palette("husl", n_colors=30))            
    else :    
        sns.boxplot(x='CONTINENTE', data=df, orient='v', y=info, order=classes,  palette=sns.color_palette("husl", n_colors=30), ax=ax)    
        
    ax.set_title(info, fontsize=20)
    ax.figure.set_size_inches(20,20) 
    ax.figure.autofmt_xdate(rotation=45)
    return ax

# %%
fig = plt.figure(constrained_layout=False)
gs = GridSpec(2, 2, figure=fig)
fig.set_size_inches(40,40)

ax0 = fig.add_subplot(gs[0, 0])
ax1 = fig.add_subplot(gs[0, 1])
ax2 = fig.add_subplot(gs[1, 0])

box_plot_continente(df, 'CASOS_POR_MILHAO', ax0)
box_plot_continente(df,'MORTES_POR_MILHAO', ax1)
box_plot_continente(df, 'LETALIDADE', ax2)
# Out:
# <AxesSubplot:title={'center':'LETALIDADE'}, xlabel='CONTINENTE', ylabel='LETALIDADE'>

# %%
box_plot_continente(df, 'CASOS_POR_MILHAO')
# Out:
# <AxesSubplot:title={'center':'CASOS_POR_MILHAO'}, xlabel='CASOS_POR_MILHAO', ylabel='CONTINENTE'>

# %%
box_plot_continente(df, 'MORTES_POR_MILHAO')
# Out:
# <AxesSubplot:title={'center':'MORTES_POR_MILHAO'}, xlabel='MORTES_POR_MILHAO', ylabel='CONTINENTE'>

# %%
box_plot_continente(df, 'LETALIDADE')
# Out:
# <AxesSubplot:title={'center':'LETALIDADE'}, xlabel='LETALIDADE', ylabel='CONTINENTE'>

# %%
def box_plot_sub_regiao(df: pd.DataFrame, info : str, ax : mplt.axes.Axes = None):
    sns.set_style("whitegrid")
    
    classes = df.SUB_REGIAO.unique()
    classes.sort()
    
    if (ax == None) :
      ax = sns.boxplot(y='SUB_REGIAO', data=df, orient='h', x=info, order=classes,  palette=sns.color_palette("husl", n_colors=30))    
    else :
      sns.boxplot(x='SUB_REGIAO', data=df, orient='v', y=info, order=classes,  palette=sns.color_palette("husl", n_colors=30), ax=ax)
    
    
    ax.set_title(info, fontsize=20)
    ax.figure.set_size_inches(20,20) 
    ax.figure.autofmt_xdate(rotation=45)
    return ax

# %%
fig = plt.figure(constrained_layout=False)
gs = GridSpec(2, 2, figure=fig)
fig.set_size_inches(60,60)

ax0 = fig.add_subplot(gs[0, 0])
ax1 = fig.add_subplot(gs[0, 1])
ax2 = fig.add_subplot(gs[1, 0])


box_plot_sub_regiao(df, 'CASOS_POR_MILHAO', ax0)
box_plot_sub_regiao(df, 'MORTES_POR_MILHAO', ax1)
box_plot_sub_regiao(df, 'LETALIDADE', ax2)
# Out:
# <AxesSubplot:title={'center':'LETALIDADE'}, xlabel='SUB_REGIAO', ylabel='LETALIDADE'>

# %%
box_plot_sub_regiao(df, 'CASOS_POR_MILHAO')
# Out:
# <AxesSubplot:title={'center':'CASOS_POR_MILHAO'}, xlabel='CASOS_POR_MILHAO', ylabel='SUB_REGIAO'>

# %%
box_plot_sub_regiao(df, 'MORTES_POR_MILHAO')
# Out:
# <AxesSubplot:title={'center':'MORTES_POR_MILHAO'}, xlabel='MORTES_POR_MILHAO', ylabel='SUB_REGIAO'>

# %%
box_plot_sub_regiao(df, 'LETALIDADE')
# Out:
# <AxesSubplot:title={'center':'LETALIDADE'}, xlabel='LETALIDADE', ylabel='SUB_REGIAO'>

# %%
dfCasosSemOutliers = df.query(f'CASOS_POR_MILHAO < {sup_casos}')
dfMortesSemOutliers = df.query(f'MORTES_POR_MILHAO < {sup_mortes}')
dfLetalidadeSemOutliers = df.query(f'LETALIDADE < {sup_letalidade}')


fig = plt.figure(constrained_layout=False)
gs = GridSpec(2, 2, figure=fig)
fig.set_size_inches(60,60)

ax0 = fig.add_subplot(gs[0, 0])
ax1 = fig.add_subplot(gs[0, 1])
ax2 = fig.add_subplot(gs[1, 0])


box_plot_sub_regiao(dfCasosSemOutliers, 'CASOS_POR_MILHAO', ax0)
box_plot_sub_regiao(dfMortesSemOutliers, 'MORTES_POR_MILHAO', ax1)
box_plot_sub_regiao(dfLetalidadeSemOutliers, 'LETALIDADE', ax2)
# Out:
# <AxesSubplot:title={'center':'LETALIDADE'}, xlabel='SUB_REGIAO', ylabel='LETALIDADE'>

# %% [markdown]
# ## Avaliação Visual de Casos / Mortes por Milhão (Boxplot)

# %% [markdown]
# ### Buscando Outliers no número de Casos e Mortes por 100 mil Habitantes

# %%
def linha_tendencia(x : pd.Series, y : pd.Series) :
    X = sm.add_constant(x)
    results = sm.OLS(y, X).fit()
    b = results.params[0]
    a = results.params[1]
    resultados = []
    for i in range(x.size) :
        if(not np.isnan(x[i])) :
            resultados.append(a * x[i] + b)
    return resultados

# %%
df.CASOS_POR_MILHAO.isna().value_counts()
# Out:
# False    182
# Name: CASOS_POR_MILHAO, dtype: int64

# %%
df.index = range(df.shape[0])
resultados = linha_tendencia(df.CASOS_POR_MILHAO, df.MORTES_POR_MILHAO)

# %%
fig, ax0 = plt.subplots()
fig.set_size_inches(8,8)
sns.scatterplot(y='MORTES_POR_MILHAO', x='CASOS_POR_MILHAO', data=df, palette='tab20', ax=ax0, hue='CONTINENTE')
ax0.set_title('Correlação das Mortes por Milhão x Casos por Milhão', fontsize=25)
ax0.set_xlabel('Casos por Milhão', fontsize=20)
ax0.set_ylabel('Mortes por Milhão', fontsize=20)
ax0.set_xlim(0, max(df.CASOS_POR_MILHAO) * 1.05)
ax0.set_ylim(0, max(df.MORTES_POR_MILHAO) * 1.05)

sns.lineplot(x = df.CASOS_POR_MILHAO, y=resultados, color='#4984af', markers=True, sort=False, label="Projeção", ax=ax0)

ax0
# Out:
# <AxesSubplot:title={'center':'Correlação das Mortes por Milhão x Casos por Milhão'}, xlabel='Casos por Milhão', ylabel='Mortes por Milhão'>

# %%
y = df['MORTES_POR_MILHAO']
X = df.CASOS_POR_MILHAO
X_Const = sm.add_constant(X)
model = sm.OLS(y,X_Const).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      MORTES_POR_MILHAO   R-squared:                       0.493
# Model:                            OLS   Adj. R-squared:                  0.490
# Method:                 Least Squares   F-statistic:                     175.1
# Date:                Fri, 22 Oct 2021   Prob (F-statistic):           2.34e-28
# Time:                        11:57:05   Log-Likelihood:                -1428.1
# No. Observations:                 182   AIC:                             2860.
# Df Residuals:                     180   BIC:                             2867.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const              138.3773     62.909      2.200      0.029      14.243     262.511
# ...

# %%
df.columns

variaveis_numericas = ['0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49',
                       '50-54', '55-59', '60-64', '65-69', '70-74', '75-79', '80-84', '85-89',
                       '90-94', '95-99', '100+', 'URBANIZACAO', 'GINI', 'GASTOS_SAUDE', 
                       'EXPECTATIVA_VIDA', 'DENSIDADE_MEDICOS',
                       'DENSIDADE_LEITOS_POR_MIL', 
                       'PIB_PER_CAPITA', 'TAXA_MORTES_CARDIOVASCULAR', 
                       'PREVALENCIA_DIABETES',
                       'LEITOS_HOSPITALARES_POR_MIL', 'IDH', 'DENSIDADE_POPULACIONAL',
                       'CASOS_POR_MILHAO', 'MORTES_POR_MILHAO', 'LETALIDADE']

sns.set_palette('summer')
ax = sns.pairplot(data=df[variaveis_numericas])
ax.fig.suptitle('Correlação entre as variáveis potencialmente explicativas', y=1.02, fontsize=20)
