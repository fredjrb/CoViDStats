# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
explicativas = ['0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49',
                '50-54', '55-59', '60-64', '65-69', '70-74', '75-79', '80-84', '85-89',
                '90-94', '95-99', '100+', 'POPULACAO', 'URBANIZACAO', 'GINI',
                'GASTOS_SAUDE', 'EXPECTATIVA_VIDA', 'DENSIDADE_MEDICOS',
                'DENSIDADE_LEITOS_POR_MIL']

dependente = ['LETALIDADE']

numericas = ['0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49',
             '50-54', '55-59', '60-64', '65-69', '70-74', '75-79', '80-84', '85-89',
             '90-94', '95-99', '100+', 'POPULACAO', 'URBANIZACAO', 'GINI',
             'GASTOS_SAUDE', 'EXPECTATIVA_VIDA', 'DENSIDADE_MEDICOS',
             'DENSIDADE_LEITOS_POR_MIL', 'LETALIDADE']

retiradas = ['CASOS', 'MORTES', 'CASOS_POR_MILHAO', 'MORTES_POR_MILHAO']

grupos_etarios = ['0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39',
                  '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75-79',
                  '80-84', '85-89', '90-94', '95-99', '100+']

df = pd.read_csv('data/consolidadoWHO.csv', sep = ',')

df.drop(axis='columns', columns=retiradas, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-caa6c8bcebd2> in <module>
#      26
#      27
# ---> 28 print(df.CASOS_POR_MILHAO.mean())
#
# C:\Desenvolvedor\Py\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'CASOS_POR_MILHAO'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-290-3a2fbbb43e7e> in <module>
#       1 dfLetalidade = pd.read_csv('data/consolidadoWHO.csv', sep = ',')
# ----> 2 dfLetalidade['LETALIDADE'] = df.MORTES / df.CASOS * 100
#       3 dfLetalidade.drop(axis='columns', columns=retiradas, inplace=True)
#       4 dfLetalidade.drop(axis='columns', columns=dependente, inplace=True)
#       5 for grupo in grupos_etarios :
#
# C:\Desenvolvedor\Py\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'MORTES'

# %%
def index_mean(data : pd.DataFrame, pais : str, indice : str):
    regiao = data.loc[data['PAIS'] == pais, 'SUB_REGIAO'].values[0]
    mean = data.query(f"SUB_REGIAO == '{regiao}'")[indice].mean()
    return mean

# %%
def full_na_with_mean(data : pd.DataFrame, indice : str): 
    dfNA = data[data[indice].isna()]
    dfNA.index = range(dfNA.shape[0])

    for i in range(dfNA.shape[0]) :
      pais = dfNA.PAIS.loc[i]
      indice_value = index_mean(data, pais, indice)
      data.loc[data['PAIS'] == pais, indice] = indice_value

# %%
full_na_with_mean(df, 'GINI')
full_na_with_mean(df, 'GASTOS_SAUDE')
full_na_with_mean(df, 'EXPECTATIVA_VIDA')
full_na_with_mean(df, 'DENSIDADE_MEDICOS')
full_na_with_mean(df, 'DENSIDADE_LEITOS_POR_MIL')
full_na_with_mean(df, 'URBANIZACAO')

full_na_with_mean(dfLetalidade, 'GINI')
full_na_with_mean(dfLetalidade, 'GASTOS_SAUDE')
full_na_with_mean(dfLetalidade, 'EXPECTATIVA_VIDA')
full_na_with_mean(dfLetalidade, 'DENSIDADE_MEDICOS')
full_na_with_mean(dfLetalidade, 'DENSIDADE_LEITOS_POR_MIL')
full_na_with_mean(dfLetalidade, 'URBANIZACAO')

df.dropna(inplace=True)
# Out:
#      AREA PAIS CONTINENTE SUB_REGIAO  ISO  0-4  5-9  10-14  15-19  20-24  ...  \
# 0     NaN  NaN        NaN        NaN  NaN  NaN  NaN    NaN    NaN    NaN  ...
# 1     NaN  NaN        NaN        NaN  NaN  NaN  NaN    NaN    NaN    NaN  ...
# 2     NaN  NaN        NaN        NaN  NaN  NaN  NaN    NaN    NaN    NaN  ...
# 3     NaN  NaN        NaN        NaN  NaN  NaN  NaN    NaN    NaN    NaN  ...
# 4     NaN  NaN        NaN        NaN  NaN  NaN  NaN    NaN    NaN    NaN  ...
# ..    ...  ...        ...        ...  ...  ...  ...    ...    ...    ...  ...
# 190   NaN  NaN        NaN        NaN  NaN  NaN  NaN    NaN    NaN    NaN  ...
# 191   NaN  NaN        NaN        NaN  NaN  NaN  NaN    NaN    NaN    NaN  ...
# 192   NaN  NaN        NaN        NaN  NaN  NaN  NaN    NaN    NaN    NaN  ...
# 193   NaN  NaN        NaN        NaN  NaN  NaN  NaN    NaN    NaN    NaN  ...
# 194   NaN  NaN        NaN        NaN  NaN  NaN  NaN    NaN    NaN    NaN  ...
#
#      95-99  100+  POPULACAO  URBANIZACAO  GINI  GASTOS_SAUDE  \
# 0      NaN   NaN        NaN          NaN   NaN           NaN
# 1      NaN   NaN        NaN          NaN   NaN           NaN
# 2      NaN   NaN        NaN          NaN   NaN           NaN
# 3      NaN   NaN        NaN          NaN   NaN           NaN
# 4      NaN   NaN        NaN          NaN   NaN           NaN
# ..     ...   ...        ...          ...   ...           ...
# 190    NaN   NaN        NaN          NaN   NaN           NaN
# 191    NaN   NaN        NaN          NaN   NaN           NaN
# 192    NaN   NaN        NaN          NaN   NaN           NaN
# 193    NaN   NaN        NaN          NaN   NaN           NaN
# 194    NaN   NaN        NaN          NaN   NaN           NaN
#
#      EXPECTATIVA_VIDA  DENSIDADE_MEDICOS  DENSIDADE_LEITOS_POR_MIL  LETALIDADE
# 0                 NaN                NaN                       NaN         NaN
# 1                 NaN                NaN                       NaN         NaN
# 2                 NaN                NaN                       NaN         NaN
# 3                 NaN                NaN                       NaN         NaN
# 4                 NaN                NaN                       NaN         NaN
# ..                ...                ...                       ...         ...
# 190               NaN                NaN                       NaN         NaN
# 191               NaN                NaN                       NaN         NaN
# 192               NaN                NaN                       NaN         NaN
# 193               NaN                NaN                       NaN         NaN
# 194               NaN                NaN                       NaN         NaN
#
# [195 rows x 34 columns]

# %%
df.isna().sum()
# Out:
# AREA                        0
# PAIS                        0
# CONTINENTE                  0
# SUB_REGIAO                  0
# ISO                         0
# 0-4                         0
# 5-9                         0
# 10-14                       0
# 15-19                       0
# 20-24                       0
# 25-29                       0
# 30-34                       0
# 35-39                       0
# 40-44                       0
# 45-49                       0
# 50-54                       0
# 55-59                       0
# 60-64                       0
# 65-69                       0
# 70-74                       0
# 75-79                       0
# 80-84                       0
# 85-89                       0
# 90-94                       0
# 95-99                       0
# 100+                        0
# POPULACAO                   0
# URBANIZACAO                 0
# GINI                        0
# GASTOS_SAUDE                0
# EXPECTATIVA_VIDA            0
# DENSIDADE_MEDICOS           0
# DENSIDADE_LEITOS_POR_MIL    0
# CASOS_POR_MILHAO            0
# dtype: int64

# %%
dfLetalidade.isna().sum()
# Out:
# AREA                        0
# PAIS                        0
# CONTINENTE                  0
# SUB_REGIAO                  0
# ISO                         0
# 0-4                         0
# 5-9                         0
# 10-14                       0
# 15-19                       0
# 20-24                       0
# 25-29                       0
# 30-34                       0
# 35-39                       0
# 40-44                       0
# 45-49                       0
# 50-54                       0
# 55-59                       0
# 60-64                       0
# 65-69                       0
# 70-74                       0
# 75-79                       0
# 80-84                       0
# 85-89                       0
# 90-94                       0
# 95-99                       0
# 100+                        0
# 25%    2.744000e+04    0.059447    0.059057    0.058469    0.058125
# 50%    1.295350e+05    0.084039    0.084507    0.084443    0.080305
# 75%    5.619368e+05    0.121775    0.118666    0.111431    0.104112
# max    1.637687e+07    0.201346    0.164530    0.139953    0.118969
#
#             20-24       25-29       30-34       35-39       40-44  ...  \
# count  186.000000  186.000000  186.000000  186.000000  186.000000  ...
# mean     0.077809    0.077046    0.075193    0.070105    0.063008  ...
# std      0.016990    0.013518    0.013694    0.014996    0.015214  ...
# min      0.040330    0.043374    0.042922    0.037847    0.033184  ...
# 25%      0.062579    0.069049    0.067050    0.061470    0.054466  ...
# 50%      0.083354    0.076612    0.073281    0.068787    0.062753  ...
# 75%      0.091878    0.085113    0.080107    0.075784    0.071944  ...
# max      0.107249    0.131491    0.164872    0.161385    0.153262  ...
#
#             95-99          100+     POPULACAO  URBANIZACAO        GINI  \
# count  186.000000  1.860000e+02  1.860000e+02   186.000000  186.000000
# mean     0.000757  1.859629e-04  4.092256e+07     0.597790   38.355284
# std      0.001336  7.614699e-04  1.460951e+08     0.229518    7.310178
# min      0.000009  4.639255e-07  3.094000e+04     0.135000   24.200000
# 25%      0.000047  3.049387e-06  2.252489e+06     0.421500   33.187500
# 50%      0.000197  1.846847e-05  9.054504e+06     0.600000   37.050000
# 75%      0.001013  1.251579e-04  3.004475e+07     0.782750   42.787500
# max      0.013058  9.017453e-03  1.394016e+09     1.000000   63.000000
#
#        GASTOS_SAUDE  EXPECTATIVA_VIDA  DENSIDADE_MEDICOS  \
# count    186.000000        186.000000         186.000000
# mean       0.064183         73.584946           1.887324
# std        0.026725          7.133158           1.707834
# min        0.016000         53.250000           0.010000
# 25%        0.045000         69.125000           0.362500
# 50%        0.062000         75.180000           1.555000
# 75%        0.079500         78.280000           2.975000
# max        0.176000         89.400000           8.420000
#
#        DENSIDADE_LEITOS_POR_MIL  LETALIDADE
# count                186.000000  186.000000
# mean                   2.887832    2.015152
# std                    2.376071    1.947738
# min                    0.100000    0.000000
# 25%                    1.300000    0.981633
# 50%                    2.212500    1.623228
# 75%                    3.800000    2.521032
# max                   13.800000   19.607843
#
# [8 rows x 30 columns]

# %%
data = df[numericas].values[:, :-1]
trans = StandardScaler()
data = trans.fit_transform(data)
dataset_explicativas = pd.DataFrame(data)
dataset_explicativas.columns = explicativas
dataset_explicativas
# Out:
#           0-4       5-9     10-14     15-19     20-24     25-29     30-34  \
# 0   -0.815473 -0.948987 -1.074736 -1.186002 -1.002797 -0.350323  1.099583
# 1   -0.115172 -0.052919  0.079436  0.327390  0.522314  0.369561  0.125486
# 2   -0.765394 -0.860042 -0.833659 -0.758247 -0.734850 -0.500713 -0.472839
# 3   -0.388086 -0.298803 -0.107033  0.160969  0.302946 -0.033122 -0.166146
# 4    0.870125  0.950792  0.936340  0.924914  0.776161  0.288966 -0.314098
# ..        ...       ...       ...       ...       ...       ...       ...
# 189 -1.017525 -1.142482 -1.304766 -1.193466 -1.103924 -1.218922 -0.966902
# 190 -1.169050 -1.215560 -1.165685 -1.038807 -1.106501 -1.690251 -1.714988
# 50-54                    -0.377344      0.274584          0.795709
# 55-59                    -0.415265      0.328333          0.769464
# 60-64                    -0.451957      0.323043          0.741571
# 65-69                    -0.464013      0.354227          0.717018
# 70-74                    -0.466613      0.374844          0.715586
# 75-79                    -0.440638      0.357733          0.704626
# 80-84                    -0.451345      0.334005          0.674094
# 85-89                    -0.434752      0.347206          0.688521
# 90-94                    -0.428801      0.341535          0.678965
# 95-99                    -0.339633      0.217425          0.581355
# 100+                     -0.148710     -0.006902          0.303930
# POPULACAO                -0.018645     -0.066526         -0.012301
# URBANIZACAO              -0.170671      0.229864          0.545793
# GINI                      1.000000     -0.115426         -0.409928
# GASTOS_SAUDE             -0.115426      1.000000          0.235697
# EXPECTATIVA_VIDA         -0.409928      0.235697          1.000000
# DENSIDADE_MEDICOS        -0.426801      0.300530          0.693747
# DENSIDADE_LEITOS_POR_MIL -0.364511      0.179261          0.470869
# CASOS_POR_MILHAO         -0.255574      0.237784          0.554464
#
#                           DENSIDADE_MEDICOS  DENSIDADE_LEITOS_POR_MIL  \
# 0-4                               -0.727319                 -0.589186
# 5-9                               -0.744135                 -0.601787
# 10-14                             -0.772483                 -0.622258
# 15-19                             -0.797552                 -0.656732
# 20-24                             -0.755255                 -0.662825
# 25-29                             -0.458830                 -0.459588
# 30-34                             -0.044437                 -0.098137
# 35-39                              0.195410                  0.092535
# 40-44                              0.429843                  0.283052
# 45-49                              0.660408                  0.518692
# 50-54                              0.720024                  0.589751
# 55-59                              0.782774                  0.646062
# 60-64                              0.774267                  0.688443
# 65-69                              0.754646                  0.676934
# 70-74                              0.757647                  0.661509
# 75-79                              0.763504                  0.661203
# 80-84                              0.792050                  0.706731
# 85-89                              0.768772                  0.668678
# 90-94                              0.747627                  0.641317
# 95-99                              0.634483                  0.582576
# 100+                               0.425568                  0.426962
# POPULACAO                         -0.053901                 -0.040412
# URBANIZACAO                        0.519150                  0.322258
# GINI                              -0.426801                 -0.364511
# GASTOS_SAUDE                       0.300530                  0.179261
# EXPECTATIVA_VIDA                   0.693747                  0.470869
# DENSIDADE_MEDICOS                  1.000000                  0.624734
# DENSIDADE_LEITOS_POR_MIL           0.624734                  1.000000
# CASOS_POR_MILHAO                   0.613081                  0.296626
#
#                           CASOS_POR_MILHAO
# 0-4                              -0.580103
# 5-9                              -0.595781
# 10-14                            -0.610372
# 15-19                            -0.610262
# 20-24                            -0.548422
# 25-29                            -0.287334
# 30-34                             0.025080
# 35-39                             0.273381
# 40-44                             0.498442
# 45-49                             0.579728
# 50-54                             0.543470
# 55-59                             0.551508
# 60-64                             0.550336
# 65-69                             0.545574
# 70-74                             0.537129
# 75-79                             0.529920
# 80-84                             0.529214
# 85-89                             0.532917
# 90-94                             0.512271
# 95-99                             0.401356
# 100+                              0.191560
# POPULACAO                        -0.080194
# URBANIZACAO                       0.477928
# GINI                             -0.255574
# GASTOS_SAUDE                      0.237784
# EXPECTATIVA_VIDA                  0.554464
# DENSIDADE_MEDICOS                 0.613081
# DENSIDADE_LEITOS_POR_MIL          0.296626
# CASOS_POR_MILHAO                  1.000000
#
# [29 rows x 29 columns]

# %%
fig, ax0 = plt.subplots()
fig.set_size_inches(15,15)
sns.heatmap(dfCorr, ax=ax0)
# Out:
# <AxesSubplot:>

# %%
dfCorr = dfLetalidade[numericas_letalidade].corr()

# %%
fig, ax0 = plt.subplots()
fig.set_size_inches(15,15)
sns.heatmap(dfCorr, ax=ax0)
# Out:
# <AxesSubplot:>

# %%
dataset_explicativas.corr()
# Out:
#                                0-4       5-9     10-14     15-19     20-24  \
# 0-4                       1.000000  0.988757  0.953866  0.884470  0.718306
# 5-9                       0.988757  1.000000  0.981083  0.914598  0.745021
# 10-14                     0.953866  0.981083  1.000000  0.962044  0.795650
# 15-19                     0.884470  0.914598  0.962044  1.000000  0.900555
# 20-24                     0.718306  0.745021  0.795650  0.900555  1.000000
# 25-29                     0.271655  0.296628  0.322925  0.433657  0.719241
# 30-34                    -0.180411 -0.153673 -0.163983 -0.122688  0.155384
# 35-39                    -0.491747 -0.468919 -0.481264 -0.463840 -0.252543
# 40-44                    -0.727668 -0.713455 -0.713335 -0.699446 -0.553133
# 45-49                    -0.902080 -0.901438 -0.892401 -0.865036 -0.756991
# 50-54                    -0.907387 -0.918193 -0.912180 -0.876876 -0.786177
# 55-59                    -0.896720 -0.911875 -0.914895 -0.896215 -0.828980
# 60-64                    -0.874751 -0.895261 -0.902229 -0.897089 -0.853133
# 65-69                    -0.832871 -0.857996 -0.864664 -0.868628 -0.855832
# 70-74                    -0.776167 -0.809191 -0.816804 -0.825357 -0.834771
# 75-79                    -0.744146 -0.780981 -0.786479 -0.788407 -0.803942
# 80-84                    -0.741180 -0.775670 -0.785674 -0.803831 -0.827884
# 85-89                    -0.714951 -0.750892 -0.759881 -0.775408 -0.804370
# 90-94                    -0.670246 -0.706688 -0.717469 -0.736257 -0.770268
# 95-99                    -0.521374 -0.560024 -0.564800 -0.565607 -0.598719
# 100+                     -0.264554 -0.293070 -0.292941 -0.283522 -0.306116
# POPULACAO                -0.033659 -0.037691 -0.039560 -0.032965 -0.027488
# URBANIZACAO              -0.502407 -0.510555 -0.527488 -0.525189 -0.419274
# GINI                      0.376614  0.388894  0.426419  0.477856  0.464067
# GASTOS_SAUDE             -0.262026 -0.280249 -0.284735 -0.274028 -0.260845
# EXPECTATIVA_VIDA         -0.832116 -0.834293 -0.822244 -0.769954 -0.630805
# DENSIDADE_MEDICOS        -0.727319 -0.744135 -0.772483 -0.797552 -0.755255
# DENSIDADE_LEITOS_POR_MIL -0.589186 -0.601787 -0.622258 -0.656732 -0.662825
#
#                              25-29     30-34     35-39     40-44     45-49  \
# 0-4                       0.271655 -0.180411 -0.491747 -0.727668 -0.902080
# 5-9                       0.296628 -0.153673 -0.468919 -0.713455 -0.901438
# 10-14                     0.322925 -0.163983 -0.481264 -0.713335 -0.892401
# 15-19                     0.433657 -0.122688 -0.463840 -0.699446 -0.865036
# 20-24                     0.719241  0.155384 -0.252543 -0.553133 -0.756991
# 25-29                     1.000000  0.710745  0.312341 -0.063842 -0.349927
# 30-34                     0.710745  1.000000  0.815423  0.465693  0.149901
# EXPECTATIVA_VIDA          ...  0.678965  0.581355  0.303930  -0.012301
# DENSIDADE_MEDICOS         ...  0.747627  0.634483  0.425568  -0.053901
# DENSIDADE_LEITOS_POR_MIL  ...  0.641317  0.582576  0.426962  -0.040412
#
#                           URBANIZACAO      GINI  GASTOS_SAUDE  \
# 0-4                         -0.502407  0.376614     -0.262026
# 5-9                         -0.510555  0.388894     -0.280249
# 10-14                       -0.527488  0.426419     -0.284735
# 15-19                       -0.525189  0.477856     -0.274028
# 20-24                       -0.419274  0.464067     -0.260845
# 25-29                       -0.136653  0.306720     -0.230816
# 30-34                        0.159124  0.068328     -0.092066
# 35-39                        0.321802 -0.084228     -0.033218
# 40-44                        0.430081 -0.234426      0.010318
# 45-49                        0.485664 -0.350249      0.141757
# 50-54                        0.451087 -0.377344      0.274584
# 55-59                        0.420830 -0.415265      0.328333
# 60-64                        0.396200 -0.451957      0.323043
# 65-69                        0.395399 -0.464013      0.354227
# 70-74                        0.432580 -0.466613      0.374844
# 75-79                        0.432244 -0.440638      0.357733
# 80-84                        0.425335 -0.451345      0.334005
# 85-89                        0.439783 -0.434752      0.347206
# 90-94                        0.441301 -0.428801      0.341535
# 95-99                        0.384465 -0.339633      0.217425
# 100+                         0.220513 -0.148710     -0.006902
# POPULACAO                   -0.037339 -0.018645     -0.066526
# URBANIZACAO                  1.000000 -0.170671      0.229864
# GINI                        -0.170671  1.000000     -0.115426
# GASTOS_SAUDE                 0.229864 -0.115426      1.000000
# EXPECTATIVA_VIDA             0.545793 -0.409928      0.235697
# DENSIDADE_MEDICOS            0.519150 -0.426801      0.300530
# DENSIDADE_LEITOS_POR_MIL     0.322258 -0.364511      0.179261
#
#                           EXPECTATIVA_VIDA  DENSIDADE_MEDICOS  \
# 0-4                              -0.832116          -0.727319
# 5-9                              -0.834293          -0.744135
# 10-14                            -0.822244          -0.772483
# 15-19                            -0.769954          -0.797552
# 20-24                            -0.630805          -0.755255
# 25-29                            -0.290558          -0.458830
# 30-34                             0.036835          -0.044437
# 35-39                             0.340012           0.195410
# 40-44                             0.589272           0.429843
# 45-49                             0.772621           0.660408
# 50-54                             0.795709           0.720024
# 55-59                             0.769464           0.782774
# 60-64                             0.741571           0.774267
# 65-69                             0.717018           0.754646
# 70-74                             0.715586           0.757647
# 75-79                             0.704626           0.763504
# 80-84                             0.674094           0.792050
# 85-89                             0.688521           0.768772
# 90-94                             0.678965           0.747627
# 95-99                             0.581355           0.634483
# 100+                              0.303930           0.425568
# POPULACAO                        -0.012301          -0.053901
# URBANIZACAO                       0.545793           0.519150
# GINI                             -0.409928          -0.426801
# GASTOS_SAUDE                      0.235697           0.300530
# EXPECTATIVA_VIDA                  1.000000           0.693747
# DENSIDADE_MEDICOS                 0.693747           1.000000
# DENSIDADE_LEITOS_POR_MIL          0.470869           0.624734
#
#                           DENSIDADE_LEITOS_POR_MIL
# 0-4                                      -0.589186
# 5-9                                      -0.601787
# 10-14                                    -0.622258
# 15-19                                    -0.656732
# 20-24                                    -0.662825
# 25-29                                    -0.459588
# 30-34                                    -0.098137
# 35-39                                     0.092535
# 40-44                                     0.283052
# 45-49                                     0.518692
# 50-54                                     0.589751
# 55-59                                     0.646062
# 60-64                                     0.688443
# 65-69                                     0.676934
# 70-74                                     0.661509
# 75-79                                     0.661203
# 80-84                                     0.706731
# 85-89                                     0.668678
# 90-94                                     0.641317
# 95-99                                     0.582576
# 100+                                      0.426962
# POPULACAO                                -0.040412
# URBANIZACAO                               0.322258
# GINI                                     -0.364511
# GASTOS_SAUDE                              0.179261
# EXPECTATIVA_VIDA                          0.470869
# DENSIDADE_MEDICOS                         0.624734
# DENSIDADE_LEITOS_POR_MIL                  1.000000
#
# [28 rows x 28 columns]

# %%
X = dataset_explicativas
y = df[dependente]

# %%
from sklearn.dummy import DummyRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

y_train = np.ravel(y_train)

models = [DummyRegressor(), DecisionTreeRegressor(), LinearRegression(), 
          SVR(), GaussianProcessRegressor(), RandomForestRegressor(), 
          ExtraTreesRegressor(), GradientBoostingRegressor(), AdaBoostRegressor()]

for model in models :
    model.fit(X_train, y_train)
    print(model.score(X_test, y_test), np.sqrt(mean_squared_error(y_test, model.predict(X_test))))
# Out:
# -0.00010141380666128796 39976.43471568262
# 0.1325341909347968 37231.30179290208
# -0.1477082618241521 42825.041497116756
# -0.20225455869221132 43830.88651984704
# -0.21848406888424643 44125.736391909166
# 0.33515375032768036 32594.374423583504
# 0.3007637296365675 33426.739152367365
# 0.21338544805990523 35453.81928419597
# 0.299694256967336 33452.292264028714

# %%
X = dataset_explicativas
y = dfLetalidade.LETALIDADE

y
# Out:
# 0      4.690538
# 1      1.340580
# 2      1.786202
# 3      2.600115
# 4      2.300129
#          ...
# 186    0.000000
# 187    0.541516
# 188    1.214575
# 189    1.831386
# 190    1.764014
# Name: LETALIDADE, Length: 186, dtype: float64

# %%
from sklearn.dummy import DummyRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

y_train = np.ravel(y_train)

models = [DummyRegressor(), DecisionTreeRegressor(), LinearRegression(), 
          SVR(), GaussianProcessRegressor(), RandomForestRegressor(), 
          ExtraTreesRegressor(), GradientBoostingRegressor(), AdaBoostRegressor()]

for model in models :
    model.fit(X_train, y_train)
    print(model.score(X_test, y_test), np.sqrt(mean_squared_error(y_test, model.predict(X_test))))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-278-26867afeb72a> in <module>
#       9 from sklearn.ensemble import AdaBoostRegressor
#      10
# ---> 11 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
#      12
#      13 y_train = np.ravel(y_train)
#
# C:\Desenvolvedor\Py\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2170         raise ValueError("At least one array required as input")
#    2171
# -> 2172     arrays = indexable(*arrays)
#    2173
#    2174     n_samples = _num_samples(arrays[0])
#
# C:\Desenvolvedor\Py\Anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     297     """
#     298     result = [_make_indexable(X) for X in iterables]
# --> 299     check_consistent_length(*result)
#     300     return result
#     301
#
# C:\Desenvolvedor\Py\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     260     uniques = np.unique(lengths)
#     261     if len(uniques) > 1:
# --> 262         raise ValueError("Found input variables with inconsistent numbers of"
#     263                          " samples: %r" % [int(l) for l in lengths])
#     264
#
# ValueError: Found input variables with inconsistent numbers of samples: [194, 186]
